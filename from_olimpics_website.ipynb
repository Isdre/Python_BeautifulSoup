# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
r = requests.get("https://olympics.com/en/olympic-games/tokyo-2020/medals")
soup = bs(r.content)
table = soup.find("div",class_="Tablestyles__CommonGrid-xjyvs9-1 Tablestyles__Content-xjyvs9-3 kSOeZM dzUKLb")
data = {"Flag":[],"Shortcut":[],"Country":[],"Gold":[],"Silver":[],"Bronze":[],"Total":[]}
images = table.find_all("div",class_="styles__Flag-sc-fehzzg-2 gmCcuH")
countries = table.find_all("div",class_="styles__CountryWrapper-sc-fehzzg-4 dVfDKJ")
gold_medals = table.find_all("div",class_="Medalstyles__Wrapper-sc-1tu6huk-0 kXFxTL",title="Gold")
silver_medals = table.find_all("div",class_="Medalstyles__Wrapper-sc-1tu6huk-0 kXFxTL",title="Silver")
bronze_medals = table.find_all("div",class_="Medalstyles__Wrapper-sc-1tu6huk-0 kXFxTL",title="Bronze")
total_medals = table.find_all("div",class_="Medalstyles__Wrapper-sc-1tu6huk-0 kXFxTL",title="")

# %%
for i,c,g,s,b,t in zip(images,countries,gold_medals,silver_medals,bronze_medals,total_medals):
    flags = i.find("source")
    flag = flags["data-srcset"].split(" ")[1]
    data["Flag"].append(flag)
    short = c.text.split(" ")
    data["Shortcut"].append(short[0])
    full_name = " ".join(short[1:])
    data["Country"].append(full_name)
    data["Gold"].append(int(g.text.replace("-","0")))
    data["Silver"].append(int(s.text.replace("-","0")))
    data["Bronze"].append(int(b.text.replace("-","0")))
    data["Total"].append(int(t.text.replace("-","0")))

# %%
# print(len(data["Flag"]))
# print(len(data["Shortcut"]))
# print(len(data["Country"]))
# print(len(data["Gold"]))
# print(len(data["Silver"]))
# print(len(data["Bronze"]))
# print(len(data["Total"]))
import pandas as pd
tab = pd.DataFrame(data=data)
print(tab["Flag"].values)
tab.to_csv("tokyo-2020_medals.csv")
# Out:
# ['https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/us'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/cn'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/jp'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/gb'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/roc'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/au'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/nl'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/fr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/de'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/it'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ca'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/br'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/nz'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/cu'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/hu'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/kr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/pl'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/cz'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ke'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/no'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/jm'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/es'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/se'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ch'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/dk'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/hr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ir'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/rs'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/be'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bg'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/si'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/uz'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ge'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/tw'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/tr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/gr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ug'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ec'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ie'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/il'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/qa'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bs'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/xk'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ua'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/by'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ve'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ro'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/in'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/hk'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/sk'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ph'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/za'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/at'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/eg'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/id'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/pt'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/et'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/tn'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/fj'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/lv'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ee'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/th'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bm'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/pr'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ma'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/co'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/az'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/do'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/am'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/kg'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/mn'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ar'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/sm'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ng'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/jo'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/my'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/lt'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/sa'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/mk'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/tm'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bh'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/na'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/kz'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/mx'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/fi'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/ci'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/kw'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bw'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/gh'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/gd'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/sy'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/md'
#  'https://gstatic.olympics.com/s1/f_auto/t_s_pog_flag_x2/static/flag/4x3/bf']
